# %%
import os.path as osp
n_eposides_tr=100 #训练集迭代生成多少个任务
n_eposides_va=100
img_size=30  #处理后的数据集图片大小
max_epoch=50
save_epoch=2
shot=1
query=3
train_way=5
test_way=5
save_path='./save_protonet'

# %% [markdown]
# # 数据集处理

# %%
import torch
import torchvision
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import PIL.ImageOps

# %%
class PronetDataset(Dataset):
    def __init__(self,imageFolderDataset,name):
        if name == 'train':
            self.data=imageFolderDataset.imgs[:2000]
        elif name == 'val':
            self.data=imageFolderDataset.imgs[2000:2300]
        elif name == 'test':
            self.data=imageFolderDataset.imgs[2300:]
        
        imgs=[]
        labels=[]
        for i in range(len(self.data)):
            path=self.data[i][0]
            label=int(path.split('\\')[-2])
            
            imgs.append(path)
            labels.append(label)
            
            
        self.imgs=imgs
        self.labels=labels
          
        self.transform = transforms.Compose([  #图片转换
            transforms.Resize(img_size),
            transforms.ToTensor()
        ])

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        path, label = self.imgs[index], self.labels[index]
        image = self.transform(Image.open(path).convert('L'))
        return image, label

# %%
import torch
import numpy as np


class CategoriesSampler():
    def __init__(self, label, n_batch, n_cls, n_per):
        self.n_batch = n_batch
        self.n_cls = n_cls  #每个任务包含的样本类别数
        self.n_per = n_per  #每个任务每个类别包含的样本数=s+q
        label = np.array(label)  #数据集的列别标签
        self.m_ind = []  #按类别储存所有样本的索引
        self.classes, self.counts = np.unique(label, return_counts=True)
        for i in self.classes:  #遍历数据集中的所有类
            ind = np.argwhere(label == i).reshape(-1)  #找出数据集中某个类别的样本索引
            ind = torch.from_numpy(ind)
            self.m_ind.append(ind)   #把每一个样本的索引按类别存放一起，后组成一个数组
        #print(self.m_ind)  #[[类别一的600个样本的索引]，[类别二,,,,,,,[]]   
    def __len__(self):
        return self.n_batch  #有多少个batch
    
    def __iter__(self):  
        for i_batch in range(self.n_batch):  #每次next(iter())生成一个eposide数据，1个eposide包含n_cls*（s+q）个样本,一个loader一共可以产生n_batch个eposide
            batch = []
            classes = torch.randperm(len(self.m_ind))[:self.n_cls]  #从数据集中随机选择n_cls个类
            for c in classes:
                l = self.m_ind[c]  #被选出的某个类的所有样本索引
                pos = torch.randperm(len(l))[:self.n_per]  #从选出的每个类中随机取出n_per个样本
                batch.append(l[pos])  
            batch = torch.stack(batch).t().reshape(-1)  #batch保存一个eposide所需的所有样本的索引，注意.t()是按（s+q）个存放
            yield batch  #返回一个n way k shot任务需要的样本，即n*(s+q)

# %%
train_dir='D:/数据库/palmdata/iitd'
batch_size=32

folder_dataset = torchvision.datasets.ImageFolder(root=train_dir)

#训练集
trainset = PronetDataset(imageFolderDataset=folder_dataset,name='train')
train_sampler = CategoriesSampler(trainset.labels, n_eposides_tr,train_way, shot + query)
train_loader = DataLoader(dataset=trainset, batch_sampler=train_sampler,num_workers=0, pin_memory=True)

#验证集
valset = PronetDataset(imageFolderDataset=folder_dataset,name='val')
val_sampler = CategoriesSampler(valset.labels, n_eposides_va,test_way, shot + query)
val_loader = DataLoader(dataset=valset, batch_sampler=val_sampler,num_workers=0, pin_memory=True)

#测试集
testset = PronetDataset(imageFolderDataset=folder_dataset,name='test')
test_sampler = CategoriesSampler(testset.labels, n_eposides_va,test_way, shot + query)
test_loader = DataLoader(dataset=testset, batch_sampler=test_sampler,num_workers=0, pin_memory=True)
# Out:
# 2000
# 300
# 300

# %% [markdown]
# # 可视化

# %%
import matplotlib.pyplot as plt

def imshow(inp):
    inp=inp.numpy().transpose((1,2,0))
    mean=np.array([[0.485,0.456,0.406]])
    std=np.array([0.229,0.224,0.225])
    inp=std*inp+mean
    inp=np.clip(inp,0,1)
    plt.imshow(inp)

x,y=next(iter(test_loader))
imshow(x[0])

# %%
# a=0
# for i, batch in enumerate(train_loader, 1):
#     a=i
#     data, label = [_.cuda() for _ in batch]
#     p = shot * train_way  #每个任务的支持集样本数
#     data_shot, data_query = data[:p], data[p:]  #一个任务的支持集样本和查询集样本
#     label_shot, label_query = label[:p], label[p:]
#     #print(label)  #[16, 19, 59, 63, 20,,随机30个数，重复15遍]，所以前p个样本为支持集，后面的样本为查询集
#     #print(len(data_shot))  #30
#     #print(len(data)) #480
#     #print(data_query[0].shape)  #([3, 28, 28])
#     #print(len(label)) #450=30*15
    
# print(a) #10=n_batch

# %% [markdown]
# # 工具函数

# %%
import os
import shutil
import time
import pprint

import torch


class Averager():

    def __init__(self):
        self.n = 0
        self.v = 0

    def add(self, x):   #每次加入一个batch计算的loss，求平均值
        self.v = (self.v * self.n + x) / (self.n + 1)
        self.n += 1

    def item(self):
        return self.v


def count_acc(logits, label):
    pred = torch.argmax(logits, dim=1)
    return (pred == label).type(torch.cuda.FloatTensor).mean().item()


def dot_metric(a, b):
    return torch.mm(a, b.t())


def euclidean_metric(a, b):
    n = a.shape[0]
    m = b.shape[0]
    a = a.unsqueeze(1).expand(n, m, -1)
    b = b.unsqueeze(0).expand(n, m, -1)
    logits = -((a - b)**2).sum(dim=2)
    return logits


class Timer():

    def __init__(self):
        self.o = time.time()  #记录起始时间

    def measure(self, p=1): #返回训练模型花费的时间
        x = (time.time() - self.o) / p
        x = int(x)
        if x >= 3600:
            return '{:.1f}h'.format(x / 3600)
        if x >= 60:
            return '{}m'.format(round(x / 60))
        return '{}s'.format(x)

_utils_pp = pprint.PrettyPrinter()
def pprint(x):
    _utils_pp.pprint(x)


def l2_loss(pred, label):
    return ((pred - label)**2).sum() / len(pred) / 2

# %% [markdown]
# # 构造模型

# %%
import torch.nn as nn


def conv_block(in_channels, out_channels):
    return nn.Sequential(
        nn.ReflectionPad2d(1),   #padding
        nn.Conv2d(in_channels, out_channels, kernel_size=3),
        nn.ReLU(inplace=True),
        nn.BatchNorm2d(out_channels),
    )


class Convnet(nn.Module):

    def __init__(self, x_dim=1, hid_dim=4, z_dim=8):
        super().__init__()
        self.encoder = nn.Sequential(  
            conv_block(x_dim, hid_dim),  
            conv_block(hid_dim, z_dim),
            conv_block(z_dim, z_dim), 
        )
        self.fc =  nn.Sequential( 
            nn.Linear(8*100*100, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 5)
        )

    def forward(self, x):
        x = self.encoder(x)
        x=x.view(x.size()[0],-1)
        return self.fc(x)   #拉直卷积运算后的特征shape为（？,1600)

# %%
import torch.nn as nn


def conv_block(in_channels, out_channels):
    bn = nn.BatchNorm2d(out_channels)
    nn.init.uniform_(bn.weight) # 随机初始化bn层的参数
    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, 3, padding=1),
        bn,
        nn.ReLU(),
        nn.MaxPool2d(2)
    )


class Convnet(nn.Module):

    def __init__(self, x_dim=1, hid_dim=64, z_dim=64):
        super().__init__()
        self.encoder = nn.Sequential(  #84=》42=》21=》10=》5
            conv_block(x_dim, hid_dim),  
            conv_block(hid_dim, hid_dim),
            conv_block(hid_dim, hid_dim),
            conv_block(hid_dim, z_dim),  
        )
        self.out_channels = 1600  #1600=5*5*64  经过卷积运算后拉直的结果

    def forward(self, x):
        x = self.encoder(x)
        return x.view(x.size(0), -1)   #拉直卷积运算后的特征shape为（？,1600)

# %%
#实例化网络
model = Convnet().cuda()
    
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)  #优化器
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)  #学习率调整器

# %% [markdown]
# # 训练模型

# %%
#把训练后的模型参数保存为args.save_path, name + '.pth'
    def save_model(name):
        torch.save(model.state_dict(), osp.join(save_path, name + '.pth'))

# %%
#记录训练每个batch的结果
trlog = {}
trlog['train_loss'] = []
trlog['val_loss'] = []
trlog['train_acc'] = []
trlog['val_acc'] = []
trlog['max_acc'] = 0.0  #记录模型最佳准确数

timer = Timer()  #用于计算训练模型花费的时间
                        #200+1
for epoch in range(1, max_epoch+1):   #训练模型迭代200轮
    lr_scheduler.step()  #初始化学习率调整器

    #模型训练
    model.train()

    tl = Averager()  #计算训练时在每个任务损失和准确数的均值
    ta = Averager()

    for i, batch in enumerate(train_loader, 1):  #此循环会进行n_batch次，每次产生一个eposide所需的数据=(s+q)*cls
        data, _ = [_.cuda() for _ in batch]   #分别把每个任务的数据data都搬到gpu上，data表示一个任务的数据=(s+q)*cls
        print(len(data))
        p = shot * train_way  #每个任务的支持集样本数
        data_shot, data_query = data[:p], data[p:]  #一个任务的支持集样本和查询集样本

        proto = model(data_shot)  #输出（支持集样本数=shot*train_way，？*？*64）
        proto = proto.reshape(shot, train_way, -1).mean(dim=0)  #计算支持集每类样本的样本均值作为该类的原型（train_way，？*？*64）

        label = torch.arange(train_way).repeat(query)  #（train_way，q）  初始化查询集每个样本对应每个类别的分数
        label = label.type(torch.cuda.LongTensor)

        logits = euclidean_metric(model(data_query), proto)  #计算查询集每个样本到每个类别原型的欧式距离，（train_way*q）
        loss = F.cross_entropy(logits, label)  #计算交叉熵损失
        acc = count_acc(logits, label)  #计算预测准率
        print('epoch {}, train {}/{}, loss={:.4f} acc={:.4f}'.format(epoch, i, len(train_loader), loss.item(), acc))

        #把一个任务的损失和准确数加入到tl和ta，用于计算在当前所有任务上的损失和准确数的均值
        tl.add(loss.item())
        ta.add(acc)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
            
        proto = None; logits = None; loss = None

    #n_batch个episode上的平均损失和准确数
    tl = tl.item()
    ta = ta.item()

    #模型验证，每n_batch个任务（train_loader走完一遍）训练完后，验证一次模型
    model.eval()

    vl = Averager()
    va = Averager()
    
    for i, batch in enumerate(val_loader, 1):
        data, _ = [_.cuda() for _ in batch]
        p = shot * test_way
        data_shot, data_query = data[:p], data[p:]
        #with torch.no_grad():？？
        proto = model(data_shot)
        proto = proto.reshape(shot, test_way, -1).mean(dim=0)

        label = torch.arange(test_way).repeat(query)
        label = label.type(torch.cuda.LongTensor)
        
        logits = euclidean_metric(model(data_query), proto)
        loss = F.cross_entropy(logits, label)
#         print(label.shape)
#         print(logits.shape)
        acc = count_acc(logits, label)

        vl.add(loss.item())
        va.add(acc)
            
        proto = None; logits = None; loss = None

    vl = vl.item()
    va = va.item()
    print('epoch {}, val, loss={:.4f} acc={:.4f}'.format(epoch, vl, va))

    # 记录模型最佳
    if va > trlog['max_acc']:
        trlog['max_acc'] = va
        save_model('max-acc')  #保存获得最佳准确率的模型

    trlog['train_loss'].append(tl)
    trlog['train_acc'].append(ta)
    trlog['val_loss'].append(vl)
    trlog['val_acc'].append(va)

    torch.save(trlog, osp.join(save_path, 'trlog'))

    save_model('epoch-last')  #保存最终的训练模型

    if epoch % save_epoch == 0:  #每save_epoch个epoch保存一次模型
        save_model('epoch-{}'.format(epoch))

    print('ETA:{}/{}'.format(timer.measure(), timer.measure(epoch / max_epoch)))
# Out:
# 20
# epoch 1, train 1/100, loss=0.8554 acc=0.8000
# 20
# epoch 1, train 2/100, loss=0.0538 acc=1.0000
# 20
# epoch 1, train 3/100, loss=0.0993 acc=1.0000
# 20
# epoch 1, train 4/100, loss=0.8074 acc=0.8000
# 20
# epoch 1, train 5/100, loss=0.7239 acc=0.8000
# 20
# epoch 1, train 6/100, loss=0.3310 acc=0.9333
# 20
# epoch 1, train 7/100, loss=0.1048 acc=0.9333
# 20
# epoch 1, train 8/100, loss=0.0543 acc=1.0000
# 20
# epoch 1, train 9/100, loss=0.8539 acc=0.6667
# 20
# epoch 1, train 10/100, loss=0.2309 acc=0.9333
# 20
# epoch 1, train 11/100, loss=0.4537 acc=0.8000
# 20
# epoch 1, train 12/100, loss=1.1156 acc=0.8667
# 20
# epoch 1, train 13/100, loss=0.1754 acc=0.8667
# 20
# epoch 1, train 14/100, loss=0.4195 acc=0.8667
# 20
# epoch 1, train 15/100, loss=0.3055 acc=0.7333
# 20
# epoch 1, train 16/100, loss=0.4276 acc=0.8667
# 20
# epoch 1, train 17/100, loss=0.4718 acc=0.8000
# 20
# epoch 1, train 18/100, loss=0.2298 acc=1.0000
# 20
# epoch 1, train 19/100, loss=0.3375 acc=0.8667
# 20
# epoch 1, train 20/100, loss=0.7437 acc=0.7333
# 20
# epoch 1, train 21/100, loss=0.0930 acc=1.0000
# 20
# epoch 1, train 22/100, loss=0.1235 acc=0.9333
# 20
# epoch 1, train 23/100, loss=1.9823 acc=0.4667
# 20
# epoch 1, train 24/100, loss=0.5092 acc=0.8000
# 20
# epoch 1, train 25/100, loss=0.4441 acc=0.8667
# 20
# epoch 1, train 26/100, loss=0.1260 acc=1.0000
# 20
# epoch 1, train 27/100, loss=0.2454 acc=0.8667
# 20
# epoch 1, train 28/100, loss=0.1473 acc=0.9333
# 20
# epoch 1, train 29/100, loss=0.3917 acc=0.8667
# 20
# epoch 1, train 30/100, loss=0.3237 acc=0.9333
# 20
# epoch 1, train 31/100, loss=0.2343 acc=0.9333
# 20
# epoch 1, train 32/100, loss=0.3915 acc=0.8000
# 20
# epoch 1, train 33/100, loss=0.4180 acc=0.8000
# 20
# epoch 1, train 34/100, loss=0.4308 acc=0.8000
# 20
# epoch 1, train 35/100, loss=0.4505 acc=0.7333
# 20
# epoch 1, train 36/100, loss=0.2636 acc=0.9333
# 20
# epoch 1, train 37/100, loss=0.1518 acc=0.9333
# 20
# epoch 1, train 38/100, loss=0.1787 acc=1.0000
# 20
# epoch 1, train 39/100, loss=0.3077 acc=0.9333
# 20
# epoch 1, train 40/100, loss=0.1284 acc=0.9333
# 20
# epoch 1, train 41/100, loss=0.5926 acc=0.8000
# 20
# epoch 1, train 42/100, loss=0.3631 acc=0.8667
# 20
# epoch 1, train 43/100, loss=0.1253 acc=1.0000
# 20
# epoch 1, train 44/100, loss=0.2983 acc=0.8667
# 20
# epoch 1, train 45/100, loss=0.2150 acc=0.9333
# 20
# epoch 1, train 46/100, loss=0.7225 acc=0.8667
# 20
# epoch 1, train 47/100, loss=0.0975 acc=1.0000
# 20
# epoch 1, train 48/100, loss=0.0610 acc=1.0000
# 20
# epoch 1, train 49/100, loss=0.5897 acc=0.8667
# 20
# epoch 1, train 50/100, loss=0.4518 acc=0.8000
# 20
# epoch 1, train 51/100, loss=0.1261 acc=1.0000
# 20
# epoch 1, train 52/100, loss=0.1974 acc=0.9333
# 20
# epoch 1, train 53/100, loss=0.6582 acc=0.8667
# 20
# epoch 1, train 54/100, loss=0.0281 acc=1.0000
# 20
# epoch 1, train 55/100, loss=0.2156 acc=0.8667
# 20
# epoch 1, train 56/100, loss=0.3730 acc=0.8667
# 20
# epoch 1, train 57/100, loss=0.3913 acc=0.9333
# 20
# epoch 1, train 58/100, loss=0.0935 acc=1.0000
# 20
# epoch 1, train 59/100, loss=0.0498 acc=1.0000
# 20
# epoch 1, train 60/100, loss=0.1355 acc=0.8667
# 20
# epoch 1, train 61/100, loss=0.1308 acc=1.0000
# 20
# epoch 1, train 62/100, loss=0.6053 acc=0.8667
# 20
# epoch 1, train 63/100, loss=0.5410 acc=0.8000
# 20
# epoch 1, train 64/100, loss=0.0260 acc=1.0000
# 20
# epoch 1, train 65/100, loss=0.0713 acc=1.0000
# 20
# epoch 1, train 66/100, loss=0.0718 acc=1.0000
# 20
# epoch 1, train 67/100, loss=0.1785 acc=0.9333
# 20
# epoch 1, train 68/100, loss=0.1480 acc=0.9333
# 20
# epoch 1, train 69/100, loss=0.0524 acc=1.0000
# 20
# epoch 1, train 70/100, loss=1.0765 acc=0.6000
# 20
# epoch 1, train 71/100, loss=0.0097 acc=1.0000
# 20
# epoch 1, train 72/100, loss=0.0403 acc=1.0000
# 20
# epoch 1, train 73/100, loss=0.3816 acc=0.8000
# 20
# epoch 1, train 74/100, loss=1.7051 acc=0.7333
# 20
# epoch 1, train 75/100, loss=0.1752 acc=0.9333
# 20
# epoch 1, train 76/100, loss=0.4619 acc=0.8667
# 20
# epoch 1, train 77/100, loss=0.0866 acc=1.0000
# 20
# epoch 1, train 78/100, loss=0.1348 acc=0.9333
# 20
# epoch 1, train 79/100, loss=0.0668 acc=1.0000
# 20
# epoch 1, train 80/100, loss=0.0685 acc=1.0000
# 20
# epoch 1, train 81/100, loss=0.0768 acc=1.0000
# 20
# epoch 1, train 82/100, loss=0.2133 acc=0.9333
# 20
# epoch 1, train 83/100, loss=0.1616 acc=0.8667
# 20
# epoch 1, train 84/100, loss=0.2225 acc=0.8667
# 20
# epoch 1, train 85/100, loss=0.0483 acc=1.0000
# 20
# epoch 1, train 86/100, loss=0.2156 acc=0.8667
# 20
# epoch 1, train 87/100, loss=0.2910 acc=0.9333
# 20
# epoch 1, train 88/100, loss=0.3565 acc=0.8667
# 20
# epoch 1, train 89/100, loss=0.1816 acc=0.9333
# 20
# epoch 1, train 90/100, loss=0.0963 acc=0.9333
# 20
# epoch 1, train 91/100, loss=0.1928 acc=0.9333
# 20
# epoch 1, train 92/100, loss=0.1626 acc=0.9333
# 20
# epoch 1, train 93/100, loss=0.1520 acc=0.9333
# 20
# epoch 1, train 94/100, loss=0.0591 acc=1.0000
# 20
# epoch 1, train 95/100, loss=0.1490 acc=0.9333
# 20
# epoch 1, train 96/100, loss=0.0902 acc=1.0000
# 20
# epoch 1, train 97/100, loss=0.0211 acc=1.0000
# 20
# epoch 1, train 98/100, loss=0.2718 acc=0.9333
# 20
# epoch 1, train 99/100, loss=0.3129 acc=0.8667
# 20
# epoch 1, train 100/100, loss=0.0821 acc=1.0000
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# epoch 1, val, loss=0.2325 acc=0.9260
# ETA:7s/6m
# 20
# epoch 2, train 1/100, loss=0.1374 acc=1.0000
# 20
# epoch 2, train 2/100, loss=0.3027 acc=0.8667
# 20
# epoch 2, train 3/100, loss=0.1429 acc=1.0000
# 20
# epoch 2, train 4/100, loss=0.1242 acc=0.9333
# 20
# epoch 2, train 5/100, loss=0.1763 acc=0.9333
# 20
# epoch 2, train 6/100, loss=0.2489 acc=0.9333
# 20
# epoch 2, train 7/100, loss=0.0072 acc=1.0000
# 20
# epoch 2, train 8/100, loss=0.3013 acc=0.8667
# 20
# epoch 2, train 9/100, loss=0.1251 acc=1.0000
# 20
# epoch 2, train 10/100, loss=0.6168 acc=0.8000
# 20
# epoch 2, train 11/100, loss=0.1065 acc=0.9333
# 20
# epoch 2, train 12/100, loss=0.2160 acc=0.9333
# 20
# epoch 2, train 13/100, loss=0.0056 acc=1.0000
# 20
# epoch 2, train 14/100, loss=0.0479 acc=1.0000
# 20
# epoch 2, train 15/100, loss=0.3419 acc=0.8667
# 20
# epoch 2, train 16/100, loss=0.1952 acc=0.9333
# 20
# epoch 2, train 17/100, loss=0.3313 acc=0.8000
# 20
# epoch 2, train 18/100, loss=0.4081 acc=0.8000
# 20
# epoch 2, train 19/100, loss=0.0293 acc=1.0000
# 20
# epoch 2, train 20/100, loss=0.0029 acc=1.0000
# 20
# epoch 2, train 21/100, loss=0.0867 acc=1.0000
# 20
# epoch 2, train 22/100, loss=0.0092 acc=1.0000
# 20
# epoch 2, train 23/100, loss=0.1330 acc=1.0000
# 20
# epoch 2, train 24/100, loss=0.0491 acc=1.0000
# 20
# epoch 2, train 25/100, loss=0.0688 acc=0.9333
# 20
# epoch 2, train 26/100, loss=0.6542 acc=0.8667
# 20
# epoch 2, train 27/100, loss=0.1704 acc=0.8667
# 20
# epoch 2, train 28/100, loss=0.0747 acc=1.0000
# 20
# epoch 2, train 29/100, loss=0.0054 acc=1.0000
# 20
# epoch 2, train 30/100, loss=0.2280 acc=0.9333
# 20
# epoch 2, train 31/100, loss=0.0048 acc=1.0000
# 20
# epoch 2, train 32/100, loss=0.2787 acc=0.8667
# 20
# epoch 2, train 33/100, loss=0.0500 acc=1.0000
# 20
# epoch 2, train 34/100, loss=0.0228 acc=1.0000
# 20
# epoch 2, train 35/100, loss=0.0294 acc=1.0000
# 20
# epoch 2, train 36/100, loss=0.5344 acc=0.9333
# 20
# epoch 2, train 37/100, loss=0.0043 acc=1.0000
# 20
# epoch 2, train 38/100, loss=0.0888 acc=1.0000
# 20
# epoch 2, train 39/100, loss=0.0385 acc=1.0000
# 20
# epoch 2, train 40/100, loss=0.0977 acc=1.0000
# 20
# epoch 2, train 41/100, loss=0.0236 acc=1.0000
# 20
# epoch 2, train 42/100, loss=0.3808 acc=0.8000
# 20
# epoch 2, train 43/100, loss=0.0726 acc=1.0000
# 20
# epoch 2, train 44/100, loss=0.0250 acc=1.0000
# 20
# epoch 2, train 45/100, loss=0.3878 acc=0.9333
# 20
# epoch 2, train 46/100, loss=0.0139 acc=1.0000
# 20
# epoch 2, train 47/100, loss=0.0176 acc=1.0000
# 20
# epoch 2, train 48/100, loss=0.1658 acc=0.9333
# 20
# epoch 2, train 49/100, loss=0.0289 acc=1.0000
# 20
# epoch 2, train 50/100, loss=0.6493 acc=0.8000
# 20
# epoch 2, train 51/100, loss=0.1145 acc=0.9333
# 20
# epoch 2, train 52/100, loss=0.0167 acc=1.0000
# 20
# epoch 2, train 53/100, loss=0.0175 acc=1.0000
# 20
# epoch 2, train 54/100, loss=0.1503 acc=0.9333
# 20
# epoch 2, train 55/100, loss=0.1360 acc=0.9333
# 20
# epoch 2, train 56/100, loss=0.8600 acc=0.7333
# 20
# epoch 2, train 57/100, loss=0.3412 acc=0.8000
# 20
# epoch 2, train 58/100, loss=0.2656 acc=0.9333
# 20
# epoch 2, train 59/100, loss=0.2824 acc=0.9333
# 20
# epoch 2, train 60/100, loss=0.0175 acc=1.0000
# 20
# epoch 2, train 61/100, loss=0.5225 acc=0.7333
# 20
# epoch 2, train 62/100, loss=0.3957 acc=0.8667
# 20
# epoch 2, train 63/100, loss=0.0952 acc=0.9333
# 20
# epoch 2, train 64/100, loss=0.0578 acc=1.0000
# 20
# epoch 2, train 65/100, loss=0.0159 acc=1.0000
# 20
# epoch 2, train 66/100, loss=0.0754 acc=1.0000
# 20
# epoch 2, train 67/100, loss=0.2750 acc=0.8667
# 20
# epoch 2, train 68/100, loss=0.0794 acc=0.9333
# 20
# epoch 2, train 69/100, loss=0.1286 acc=0.9333
# 20
# epoch 2, train 70/100, loss=0.0159 acc=1.0000
# 20
# epoch 2, train 71/100, loss=0.0061 acc=1.0000
# 20
# epoch 2, train 72/100, loss=0.2018 acc=0.9333
# 20
# epoch 2, train 73/100, loss=0.0151 acc=1.0000
# 20
# epoch 2, train 74/100, loss=0.1077 acc=1.0000
# 20
# epoch 2, train 75/100, loss=0.0221 acc=1.0000
# 20
# epoch 2, train 76/100, loss=0.0138 acc=1.0000
# 20
# epoch 2, train 77/100, loss=0.0031 acc=1.0000
# 20
# epoch 2, train 78/100, loss=0.2709 acc=0.9333
# 20
# epoch 2, train 79/100, loss=0.1804 acc=1.0000
# 20
# epoch 2, train 80/100, loss=0.0186 acc=1.0000
# 20
# epoch 2, train 81/100, loss=0.4312 acc=0.8667
# 20
# epoch 2, train 82/100, loss=0.5318 acc=0.8667
# 20
# epoch 2, train 83/100, loss=0.2839 acc=0.9333
# 20
# epoch 2, train 84/100, loss=0.6839 acc=0.8000
# 20
# epoch 2, train 85/100, loss=0.3602 acc=0.8667
# 20
# epoch 2, train 86/100, loss=0.3877 acc=0.9333
# 20
# epoch 2, train 87/100, loss=0.1033 acc=1.0000
# 20
# epoch 2, train 88/100, loss=0.5344 acc=0.8667
# 20
# epoch 2, train 89/100, loss=0.2349 acc=0.8000
# 20
# epoch 2, train 90/100, loss=0.0876 acc=1.0000
# 20
# epoch 2, train 91/100, loss=0.1908 acc=0.8667
# 20
# epoch 2, train 92/100, loss=0.0374 acc=1.0000
# 20
# epoch 2, train 93/100, loss=0.1175 acc=1.0000
# 20
# epoch 2, train 94/100, loss=0.1012 acc=1.0000
# 20
# epoch 2, train 95/100, loss=0.0071 acc=1.0000
# 20
# epoch 2, train 96/100, loss=0.4761 acc=0.7333
# 20
# epoch 2, train 97/100, loss=0.4291 acc=0.8667
# 20
# epoch 2, train 98/100, loss=0.1573 acc=0.9333
# 20
# epoch 2, train 99/100, loss=0.0151 acc=1.0000
# 20
# epoch 2, train 100/100, loss=0.2918 acc=0.8667
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# epoch 2, val, loss=0.2491 acc=0.9273
# ETA:14s/6m
# 20
# epoch 3, train 1/100, loss=0.0875 acc=0.9333
# 20
# epoch 3, train 2/100, loss=0.0676 acc=1.0000
# 20
# epoch 3, train 3/100, loss=0.2319 acc=0.9333
# 20
# epoch 3, train 4/100, loss=0.2983 acc=0.9333
# 20
# epoch 3, train 5/100, loss=0.2871 acc=0.9333
# 20
# epoch 3, train 6/100, loss=0.0079 acc=1.0000
# 20
# epoch 3, train 7/100, loss=0.1935 acc=0.9333
# 20
# epoch 3, train 8/100, loss=0.2155 acc=0.9333
# 20
# epoch 3, train 9/100, loss=0.5894 acc=0.8000
# 20
# epoch 3, train 10/100, loss=0.1190 acc=1.0000
# 20
# epoch 3, train 11/100, loss=0.2141 acc=0.8667
# 20
# epoch 3, train 12/100, loss=0.7715 acc=0.8000
# 20
# epoch 3, train 13/100, loss=0.0588 acc=1.0000
# 20
# epoch 3, train 14/100, loss=0.3098 acc=0.9333
# 20
# epoch 3, train 15/100, loss=0.3816 acc=0.8667
# 20
# epoch 3, train 16/100, loss=0.1816 acc=0.9333
# 20
# epoch 3, train 17/100, loss=0.0361 acc=1.0000
# 20
# epoch 3, train 18/100, loss=0.1614 acc=0.9333
# 20
# epoch 3, train 19/100, loss=0.2038 acc=0.9333
# 20
# epoch 3, train 20/100, loss=0.0222 acc=1.0000
# 20
# epoch 3, train 21/100, loss=0.0642 acc=1.0000
# 20
# epoch 3, train 22/100, loss=1.0550 acc=0.8667
# 20
# epoch 3, train 23/100, loss=0.4887 acc=0.8000
# 20
# epoch 3, train 24/100, loss=0.1639 acc=0.9333
# 20
# epoch 3, train 25/100, loss=0.1191 acc=1.0000
# 20
# epoch 3, train 26/100, loss=0.1091 acc=1.0000
# 20
# epoch 3, train 27/100, loss=0.1188 acc=1.0000
# 20
# epoch 3, train 28/100, loss=0.3179 acc=0.8667
# 20
# epoch 3, train 29/100, loss=0.2022 acc=0.9333
# 20
# epoch 3, train 30/100, loss=0.0890 acc=1.0000
# 20
# epoch 3, train 31/100, loss=0.0399 acc=1.0000
# 20
# epoch 3, train 32/100, loss=0.1954 acc=0.9333
# 20
# epoch 3, train 33/100, loss=0.1539 acc=0.9333
# 20
# epoch 3, train 34/100, loss=0.0242 acc=1.0000
# 20
# epoch 3, train 35/100, loss=0.0654 acc=1.0000
# 20
# epoch 3, train 36/100, loss=0.0072 acc=1.0000
# 20
# epoch 3, train 37/100, loss=0.3852 acc=0.8667
# 20
# epoch 3, train 38/100, loss=0.0879 acc=1.0000
# 20
# epoch 3, train 39/100, loss=0.0115 acc=1.0000
# 20
# epoch 3, train 40/100, loss=0.3887 acc=0.8000
# 20
# epoch 3, train 41/100, loss=0.0478 acc=1.0000
# 20
# epoch 3, train 42/100, loss=1.9183 acc=0.7333
# 20
# epoch 3, train 43/100, loss=0.0699 acc=1.0000
# 20
# epoch 3, train 44/100, loss=0.1651 acc=0.9333
# 20
# epoch 3, train 45/100, loss=0.1220 acc=0.9333
# 20
# epoch 3, train 46/100, loss=0.1338 acc=0.8667
# 20
# epoch 3, train 47/100, loss=0.0104 acc=1.0000
# 20
# epoch 3, train 48/100, loss=0.2187 acc=0.8667
# 20
# epoch 3, train 49/100, loss=0.0338 acc=1.0000
# 20
# epoch 3, train 50/100, loss=0.2065 acc=0.8667
# 20
# epoch 3, train 51/100, loss=0.1928 acc=0.9333
# 20
# epoch 3, train 52/100, loss=0.0887 acc=0.9333
# 20
# epoch 3, train 53/100, loss=0.6135 acc=0.8000
# 20
# epoch 3, train 54/100, loss=0.0456 acc=1.0000
# 20
# epoch 3, train 55/100, loss=0.7387 acc=0.8000
# 20
# epoch 3, train 56/100, loss=0.0323 acc=1.0000
# 20
# epoch 3, train 57/100, loss=0.1432 acc=0.9333
# 20
# epoch 3, train 58/100, loss=0.0733 acc=1.0000
# 20
# epoch 3, train 59/100, loss=0.8645 acc=0.7333
# 20
# epoch 3, train 60/100, loss=0.0835 acc=1.0000
# 20
# epoch 3, train 61/100, loss=0.0454 acc=1.0000
# 20
# epoch 3, train 62/100, loss=0.4043 acc=0.8667
# 20
# epoch 3, train 63/100, loss=0.0247 acc=1.0000
# 20
# epoch 3, train 64/100, loss=0.3052 acc=0.9333
# 20
# epoch 3, train 65/100, loss=0.1308 acc=0.9333
# 20
# epoch 3, train 66/100, loss=0.1196 acc=0.9333
# 20
# epoch 3, train 67/100, loss=0.0134 acc=1.0000
# 20
# epoch 3, train 68/100, loss=0.0744 acc=1.0000
# 20
# epoch 3, train 69/100, loss=0.0139 acc=1.0000
# 20
# epoch 3, train 70/100, loss=0.0085 acc=1.0000
# 20
# epoch 3, train 71/100, loss=0.7615 acc=0.8000
# 20
# epoch 3, train 72/100, loss=0.1426 acc=0.9333
# 20
# epoch 3, train 73/100, loss=0.1133 acc=0.9333
# 20
# epoch 3, train 74/100, loss=0.0165 acc=1.0000
# 20
# epoch 3, train 75/100, loss=0.2777 acc=0.8667
# 20
# epoch 3, train 76/100, loss=0.0854 acc=1.0000
# 20
# epoch 3, train 77/100, loss=0.1483 acc=0.9333
# 20
# epoch 3, train 78/100, loss=0.0599 acc=1.0000
# 20
# epoch 3, train 79/100, loss=0.0184 acc=1.0000
# 20
# epoch 3, train 80/100, loss=0.0832 acc=1.0000
# 20
# epoch 3, train 81/100, loss=0.0199 acc=1.0000
# 20
# epoch 3, train 82/100, loss=0.1509 acc=1.0000
# 20
# epoch 3, train 83/100, loss=0.0352 acc=1.0000
# 20
# epoch 3, train 84/100, loss=0.3612 acc=0.9333
# 20
# epoch 3, train 85/100, loss=0.8743 acc=0.6667
# 20
# epoch 3, train 86/100, loss=1.8530 acc=0.6667
# 20
# epoch 3, train 87/100, loss=0.0034 acc=1.0000
# 20
# epoch 3, train 88/100, loss=0.0140 acc=1.0000
# 20
# epoch 3, train 89/100, loss=0.2357 acc=0.8667
# 20
# epoch 3, train 90/100, loss=0.2275 acc=0.9333
# 20
# epoch 3, train 91/100, loss=0.2616 acc=0.8667
# 20
# epoch 3, train 92/100, loss=0.0829 acc=0.9333
# 20
# epoch 3, train 93/100, loss=0.0598 acc=0.9333
# 20
# epoch 3, train 94/100, loss=0.1322 acc=1.0000
# 20
# epoch 3, train 95/100, loss=0.3336 acc=0.8667
# 20
# epoch 3, train 96/100, loss=0.1358 acc=0.9333
# 20
# epoch 3, train 97/100, loss=0.0458 acc=1.0000
# 20
# epoch 3, train 98/100, loss=0.0607 acc=1.0000
# 20
# epoch 3, train 99/100, loss=0.3849 acc=0.8000
# 20
# epoch 3, train 100/100, loss=0.1721 acc=0.9333
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# epoch 3, val, loss=0.2151 acc=0.9387
# ETA:20s/6m
# 20
# epoch 4, train 1/100, loss=0.0883 acc=1.0000
# 20
# epoch 4, train 2/100, loss=0.4952 acc=0.8000
# 20
# epoch 4, train 3/100, loss=0.0098 acc=1.0000
# 20
# epoch 4, train 4/100, loss=0.0163 acc=1.0000
# 20
# epoch 4, train 5/100, loss=0.0973 acc=1.0000
# 20
# epoch 4, train 6/100, loss=0.2413 acc=0.9333
# 20
# epoch 4, train 7/100, loss=0.0062 acc=1.0000
# 20
# epoch 4, train 8/100, loss=0.2580 acc=0.8667
# 20
# epoch 4, train 9/100, loss=0.9505 acc=0.7333
# 20
# epoch 4, train 10/100, loss=0.1415 acc=1.0000
# 20
# epoch 4, train 11/100, loss=0.0461 acc=1.0000
# 20
# epoch 4, train 12/100, loss=0.6872 acc=0.7333
# 20
# epoch 4, train 13/100, loss=0.1966 acc=0.9333
# 20
# epoch 4, train 14/100, loss=0.3984 acc=0.8000
# 20
# epoch 4, train 15/100, loss=0.0534 acc=1.0000
# 20
# epoch 4, train 16/100, loss=0.0488 acc=1.0000
# 20
# epoch 4, train 17/100, loss=0.0123 acc=1.0000
# 20
# epoch 4, train 18/100, loss=0.0371 acc=1.0000
# 20
# epoch 4, train 19/100, loss=0.1391 acc=1.0000
# 20
# epoch 4, train 20/100, loss=0.2999 acc=0.8000
# 20
# epoch 4, train 21/100, loss=0.0600 acc=1.0000
# 20
# epoch 4, train 22/100, loss=0.0037 acc=1.0000
# 20
# epoch 4, train 23/100, loss=0.1521 acc=0.9333
# 20
# epoch 4, train 24/100, loss=0.0178 acc=1.0000
# 20
# epoch 4, train 25/100, loss=0.1345 acc=0.9333
# 20
# epoch 4, train 26/100, loss=0.2222 acc=0.9333
# 20
# epoch 4, train 27/100, loss=0.0325 acc=1.0000
# 20
# epoch 4, train 28/100, loss=0.0682 acc=1.0000
# 20
# epoch 4, train 29/100, loss=0.0898 acc=0.9333
# 20
# epoch 4, train 30/100, loss=0.1236 acc=0.9333
# 20
# epoch 4, train 31/100, loss=0.1511 acc=0.9333
# 20
# epoch 4, train 32/100, loss=0.0055 acc=1.0000
# 20
# epoch 4, train 33/100, loss=0.1493 acc=0.9333
# 20
# epoch 4, train 34/100, loss=0.1338 acc=0.9333
# 20
# epoch 4, train 35/100, loss=0.1058 acc=0.9333
# 20
# epoch 4, train 36/100, loss=0.2510 acc=0.9333
# 20
# epoch 4, train 37/100, loss=0.0059 acc=1.0000
# 20
# epoch 4, train 38/100, loss=0.0171 acc=1.0000
# 20
# epoch 4, train 39/100, loss=0.0449 acc=1.0000
# 20
# epoch 4, train 40/100, loss=0.0648 acc=1.0000
# 20
# epoch 4, train 41/100, loss=0.1459 acc=0.9333
# 20
# epoch 4, train 42/100, loss=0.0455 acc=1.0000
# 20
# epoch 4, train 43/100, loss=0.0458 acc=1.0000
# 20
# epoch 4, train 44/100, loss=0.0032 acc=1.0000
# 20
# epoch 4, train 45/100, loss=0.0463 acc=1.0000
# 20
# epoch 4, train 46/100, loss=0.0491 acc=1.0000
# 20
# epoch 4, train 47/100, loss=0.0326 acc=1.0000
# 20
# epoch 4, train 48/100, loss=0.0103 acc=1.0000
# 20
# epoch 4, train 49/100, loss=0.0409 acc=1.0000
# 20
# epoch 4, train 50/100, loss=0.0513 acc=1.0000
# 20
# epoch 4, train 51/100, loss=0.0001 acc=1.0000
# 20
# epoch 4, train 52/100, loss=0.1294 acc=0.9333
# 20
# epoch 4, train 53/100, loss=0.0263 acc=1.0000
# 20
# epoch 4, train 54/100, loss=0.0340 acc=1.0000
# 20
# epoch 4, train 55/100, loss=0.0747 acc=1.0000
# 20
# epoch 4, train 56/100, loss=0.0095 acc=1.0000
# 20
# epoch 4, train 57/100, loss=0.0092 acc=1.0000
# 20
# epoch 4, train 58/100, loss=0.0029 acc=1.0000
# 20
# epoch 4, train 59/100, loss=0.1270 acc=0.9333
# 20
# epoch 4, train 60/100, loss=0.0011 acc=1.0000
# 20
# epoch 4, train 61/100, loss=0.0008 acc=1.0000
# 20
# epoch 4, train 62/100, loss=0.3677 acc=0.8000
# 20
# epoch 4, train 63/100, loss=0.0073 acc=1.0000
# 20
# epoch 4, train 64/100, loss=0.0038 acc=1.0000
# 20
# epoch 4, train 65/100, loss=0.9099 acc=0.6667
# 20
# epoch 4, train 66/100, loss=0.0048 acc=1.0000
# 20
# epoch 4, train 67/100, loss=0.0048 acc=1.0000
# 20
# epoch 4, train 68/100, loss=0.0031 acc=1.0000
# 20
# epoch 4, train 69/100, loss=0.0953 acc=1.0000
# 20
# epoch 4, train 70/100, loss=0.1539 acc=0.9333
# 20
# epoch 4, train 71/100, loss=0.0155 acc=1.0000
# 20
# epoch 4, train 72/100, loss=0.0069 acc=1.0000
# 20
# epoch 4, train 73/100, loss=0.0011 acc=1.0000
# 20
# epoch 4, train 74/100, loss=0.0003 acc=1.0000
# 20
# epoch 4, train 75/100, loss=0.2473 acc=0.9333
# 20
# epoch 4, train 76/100, loss=1.1600 acc=0.8667
# 20
# epoch 4, train 77/100, loss=0.2662 acc=0.8667
# 20
# epoch 4, train 78/100, loss=0.0565 acc=1.0000
# 20
# epoch 4, train 79/100, loss=0.1344 acc=0.9333
# 20
# epoch 4, train 80/100, loss=0.0653 acc=1.0000
# 20
# epoch 4, train 81/100, loss=0.0328 acc=1.0000
# 20
# epoch 4, train 82/100, loss=0.2933 acc=0.9333
# 20
# epoch 4, train 83/100, loss=0.1231 acc=0.9333
# 20
# epoch 4, train 84/100, loss=0.0269 acc=1.0000
# 20
# epoch 4, train 85/100, loss=0.1222 acc=1.0000
# 20
# epoch 4, train 86/100, loss=0.0744 acc=1.0000
# 20
# epoch 4, train 87/100, loss=0.4792 acc=0.9333
# 20
# epoch 4, train 88/100, loss=0.0977 acc=1.0000
# 20
# epoch 4, train 89/100, loss=0.1893 acc=0.8667
# 20
# epoch 4, train 90/100, loss=0.1692 acc=0.9333
# 20
# epoch 4, train 91/100, loss=0.0226 acc=1.0000
# 20
# epoch 4, train 92/100, loss=0.1520 acc=0.9333
# 20
# epoch 4, train 93/100, loss=0.0523 acc=1.0000
# 20
# epoch 4, train 94/100, loss=0.3907 acc=0.8667
# 20
# epoch 4, train 95/100, loss=0.1626 acc=0.9333
# 20
# epoch 4, train 96/100, loss=0.1800 acc=0.8667
# 20
# epoch 4, train 97/100, loss=0.0206 acc=1.0000
# 20
# epoch 4, train 98/100, loss=0.5802 acc=0.8000
# 20
# epoch 4, train 99/100, loss=0.0772 acc=0.9333
# 20
# epoch 4, train 100/100, loss=0.0078 acc=1.0000
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# epoch 4, val, loss=0.2107 acc=0.9407
# ETA:27s/6m
# 20
# epoch 5, train 1/100, loss=0.0647 acc=0.9333
# 20
# epoch 5, train 2/100, loss=0.3496 acc=0.8667
# 20
# epoch 5, train 3/100, loss=0.0644 acc=0.9333
# 20
# epoch 5, train 4/100, loss=0.0446 acc=1.0000
# 20
# epoch 5, train 5/100, loss=0.0385 acc=1.0000
# 20
# epoch 5, train 6/100, loss=0.0702 acc=1.0000
# 20
# epoch 5, train 7/100, loss=0.0075 acc=1.0000
# 20
# epoch 5, train 8/100, loss=0.0218 acc=1.0000
# 20
# epoch 5, train 9/100, loss=0.1023 acc=0.9333
# 20
# epoch 5, train 10/100, loss=0.0029 acc=1.0000
# 20
# epoch 5, train 11/100, loss=0.5259 acc=0.8000
# 20
# epoch 5, train 12/100, loss=0.0534 acc=1.0000
# 20
# epoch 5, train 13/100, loss=0.6221 acc=0.9333
# 20
# epoch 5, train 14/100, loss=0.0259 acc=1.0000
# 20
# epoch 5, train 15/100, loss=0.2322 acc=0.9333
# 20
# epoch 5, train 16/100, loss=0.0825 acc=0.9333
# 20
# epoch 5, train 17/100, loss=0.4106 acc=0.9333
# 20
# epoch 5, train 18/100, loss=0.0743 acc=1.0000
# 20
# epoch 5, train 19/100, loss=0.0248 acc=1.0000
# 20
# epoch 5, train 20/100, loss=0.1496 acc=0.9333
# 20
# epoch 5, train 21/100, loss=0.0177 acc=1.0000
# 20
# epoch 5, train 22/100, loss=0.0036 acc=1.0000
# 20
# epoch 5, train 23/100, loss=0.0506 acc=1.0000
# 20
# epoch 5, train 24/100, loss=0.0116 acc=1.0000
# 20
# epoch 5, train 25/100, loss=0.0543 acc=1.0000
# 20
# epoch 5, train 26/100, loss=0.1992 acc=0.9333
# 20
# epoch 5, train 27/100, loss=0.1757 acc=0.8667
# 20
# epoch 5, train 28/100, loss=0.1205 acc=0.9333
# 20
# epoch 5, train 29/100, loss=0.0652 acc=0.9333
# 20
# epoch 5, train 30/100, loss=0.1636 acc=0.9333
# 20
# epoch 5, train 31/100, loss=0.0908 acc=1.0000
# 20
# epoch 5, train 32/100, loss=0.0003 acc=1.0000
# 20
# epoch 5, train 33/100, loss=0.0263 acc=1.0000
# 20
# epoch 5, train 34/100, loss=0.0031 acc=1.0000
# 20
# epoch 5, train 35/100, loss=0.0033 acc=1.0000
# 20
# epoch 5, train 36/100, loss=0.0522 acc=1.0000
# 20
# epoch 5, train 37/100, loss=0.0216 acc=1.0000
# 20
# epoch 5, train 38/100, loss=0.0129 acc=1.0000
# 20
# epoch 5, train 39/100, loss=0.2694 acc=0.9333
# 20
# epoch 5, train 40/100, loss=0.0113 acc=1.0000
# 20
# epoch 5, train 41/100, loss=0.1384 acc=0.9333
# 20
# epoch 5, train 42/100, loss=0.0139 acc=1.0000
# 20
# epoch 5, train 43/100, loss=0.0017 acc=1.0000
# 20
# epoch 5, train 44/100, loss=0.1274 acc=0.9333
# 20
# epoch 5, train 45/100, loss=0.0598 acc=1.0000
# 20
# epoch 5, train 46/100, loss=0.0107 acc=1.0000
# 20
# epoch 5, train 47/100, loss=0.0664 acc=0.9333
# 20
# epoch 5, train 48/100, loss=0.0642 acc=1.0000
# 20
# epoch 5, train 49/100, loss=0.0402 acc=1.0000
# 20
# epoch 5, train 50/100, loss=0.0134 acc=1.0000
# 20
# epoch 5, train 51/100, loss=0.0319 acc=1.0000
# 20
# epoch 5, train 52/100, loss=0.0014 acc=1.0000
# 20
# epoch 5, train 53/100, loss=0.0078 acc=1.0000
# 20
# epoch 5, train 54/100, loss=0.0017 acc=1.0000
# 20
# epoch 5, train 55/100, loss=0.5412 acc=0.8667
# 20
# epoch 5, train 56/100, loss=0.0284 acc=1.0000
# 20
# epoch 5, train 57/100, loss=0.0968 acc=1.0000
# 20
# epoch 5, train 58/100, loss=0.3800 acc=0.8667
# 20
# epoch 5, train 59/100, loss=0.0413 acc=1.0000
# 20
# epoch 5, train 60/100, loss=0.0191 acc=1.0000
# 20
# epoch 5, train 61/100, loss=0.0262 acc=1.0000
# 20
# epoch 5, train 62/100, loss=0.0081 acc=1.0000
# 20
# epoch 5, train 63/100, loss=0.0383 acc=1.0000
# 20
# epoch 5, train 64/100, loss=0.0016 acc=1.0000
# 20
# epoch 5, train 65/100, loss=0.6221 acc=0.8667
# 20
# epoch 5, train 66/100, loss=0.0036 acc=1.0000
# 20
# epoch 5, train 67/100, loss=0.0021 acc=1.0000
# 20
# epoch 5, train 68/100, loss=0.0071 acc=1.0000
# 20
# epoch 5, train 69/100, loss=0.1080 acc=1.0000
# 20
# epoch 5, train 70/100, loss=0.1187 acc=0.9333
# 20
# epoch 5, train 71/100, loss=0.0035 acc=1.0000
# 20
# epoch 5, train 72/100, loss=0.1228 acc=0.9333
# 20
# epoch 5, train 73/100, loss=0.0108 acc=1.0000
# 20
# epoch 5, train 74/100, loss=0.0040 acc=1.0000
# 20
# epoch 5, train 75/100, loss=0.0369 acc=1.0000
# 20
# epoch 5, train 76/100, loss=0.0240 acc=1.0000
# 20
# epoch 5, train 77/100, loss=0.0006 acc=1.0000
# 20
# epoch 5, train 78/100, loss=0.2165 acc=0.9333
# 20
# epoch 5, train 79/100, loss=0.1044 acc=0.9333
# 20
# epoch 5, train 80/100, loss=0.0039 acc=1.0000
# 20
# epoch 5, train 81/100, loss=0.0081 acc=1.0000
# 20
# epoch 5, train 82/100, loss=0.0635 acc=1.0000
# 20
# epoch 5, train 83/100, loss=0.0875 acc=1.0000
# 20
# epoch 5, train 84/100, loss=0.0471 acc=1.0000
# 20
# epoch 5, train 85/100, loss=0.1284 acc=0.9333
# 20
# epoch 5, train 86/100, loss=0.2038 acc=0.9333
# 20
# epoch 5, train 87/100, loss=0.0153 acc=1.0000
# 20
# epoch 5, train 88/100, loss=0.0639 acc=1.0000
# 20
# epoch 5, train 89/100, loss=0.0007 acc=1.0000
# 20
# epoch 5, train 90/100, loss=0.0247 acc=1.0000
# 20
# epoch 5, train 91/100, loss=0.0129 acc=1.0000
# 20
# epoch 5, train 92/100, loss=0.0504 acc=1.0000
# 20
# epoch 5, train 93/100, loss=0.0007 acc=1.0000
# 20
# epoch 5, train 94/100, loss=0.0481 acc=1.0000
# 20
# epoch 5, train 95/100, loss=0.0145 acc=1.0000
# 20
# epoch 5, train 96/100, loss=0.0458 acc=1.0000
# 20
# epoch 5, train 97/100, loss=0.0161 acc=1.0000
# 20
# epoch 5, train 98/100, loss=0.0009 acc=1.0000
# 20
# epoch 5, train 99/100, loss=0.0268 acc=1.0000
# 20
# epoch 5, train 100/100, loss=0.0138 acc=1.0000
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# epoch 5, val, loss=0.1715 acc=0.9520
# ETA:34s/6m
# 20
# epoch 6, train 1/100, loss=0.0298 acc=1.0000
# 20
# epoch 6, train 2/100, loss=0.1843 acc=0.9333
# 20
# epoch 6, train 3/100, loss=0.4749 acc=0.8667
# 20
# epoch 6, train 4/100, loss=0.0041 acc=1.0000
# 20
# epoch 6, train 5/100, loss=0.3263 acc=0.9333
# 20
# epoch 6, train 6/100, loss=0.0196 acc=1.0000
# 20
# epoch 6, train 7/100, loss=0.0075 acc=1.0000
# 20
# epoch 6, train 8/100, loss=0.1562 acc=0.9333
# 20
# epoch 6, train 9/100, loss=0.0036 acc=1.0000
# 20
# epoch 6, train 10/100, loss=0.1371 acc=0.9333
# 20
# epoch 6, train 11/100, loss=0.0610 acc=1.0000
# 20
# epoch 6, train 12/100, loss=0.2949 acc=0.9333
# 20
# epoch 6, train 13/100, loss=0.0431 acc=1.0000
# 20
# epoch 6, train 14/100, loss=0.0088 acc=1.0000
# 20
# epoch 6, train 15/100, loss=0.0141 acc=1.0000
# 20
# epoch 6, train 16/100, loss=0.0069 acc=1.0000
# 20
# epoch 6, train 17/100, loss=0.0125 acc=1.0000
# 20
# epoch 6, train 18/100, loss=0.1998 acc=0.9333
# 20
# epoch 6, train 19/100, loss=1.2348 acc=0.8000
# 20
# epoch 6, train 20/100, loss=0.0017 acc=1.0000
# 20
# epoch 6, train 21/100, loss=0.0016 acc=1.0000
# 20
# epoch 6, train 22/100, loss=0.0232 acc=1.0000
# 20
# epoch 6, train 23/100, loss=0.0606 acc=0.9333
# 20
# epoch 6, train 24/100, loss=0.0031 acc=1.0000
# 20
# epoch 6, train 25/100, loss=0.8262 acc=0.9333
# 20
# epoch 6, train 26/100, loss=0.2614 acc=0.8000
# 20
# epoch 6, train 27/100, loss=0.0039 acc=1.0000
# 20
# epoch 6, train 28/100, loss=0.3838 acc=0.9333
# 20
# epoch 6, train 29/100, loss=0.0106 acc=1.0000
# 20
# epoch 6, train 30/100, loss=0.0253 acc=1.0000
# 20
# epoch 6, train 31/100, loss=0.0521 acc=1.0000
# 20
# epoch 6, train 32/100, loss=0.2381 acc=0.9333
# 20
# epoch 6, train 33/100, loss=0.2502 acc=0.8000
# 20
# epoch 6, train 34/100, loss=0.0048 acc=1.0000
# 20
# epoch 6, train 35/100, loss=0.3721 acc=0.9333
# 20
# epoch 6, train 36/100, loss=0.9207 acc=0.8000
# 20
# epoch 6, train 37/100, loss=0.1066 acc=0.9333
# 20
# epoch 6, train 38/100, loss=0.0017 acc=1.0000
# 20
# epoch 6, train 39/100, loss=0.1931 acc=0.8667
# 20
# epoch 6, train 40/100, loss=0.0771 acc=1.0000
# 20
# epoch 6, train 41/100, loss=0.2231 acc=0.9333
# 20
# epoch 6, train 42/100, loss=0.0020 acc=1.0000
# 20
# epoch 6, train 43/100, loss=0.0333 acc=1.0000
# 20
# epoch 6, train 44/100, loss=0.0462 acc=1.0000
# 20
# epoch 6, train 45/100, loss=0.1114 acc=1.0000
# 20
# epoch 6, train 46/100, loss=0.1233 acc=1.0000
# 20
# epoch 6, train 47/100, loss=0.2942 acc=0.9333
# 20
# epoch 6, train 48/100, loss=0.0031 acc=1.0000
# 20
# epoch 6, train 49/100, loss=0.4482 acc=0.8667
# 20
# epoch 6, train 50/100, loss=0.1497 acc=0.9333
# 20
# epoch 6, train 51/100, loss=0.0117 acc=1.0000
# 20
# epoch 6, train 52/100, loss=0.0146 acc=1.0000
# 20
# epoch 6, train 53/100, loss=0.5211 acc=0.8667
# 20
# epoch 6, train 54/100, loss=0.0146 acc=1.0000
# 20
# epoch 6, train 55/100, loss=0.0281 acc=1.0000
# 20
# epoch 6, train 56/100, loss=0.0880 acc=0.9333
# 20
# epoch 6, train 57/100, loss=0.0042 acc=1.0000
# 20
# epoch 6, train 58/100, loss=0.0085 acc=1.0000
# 20
# epoch 6, train 59/100, loss=0.0020 acc=1.0000
# 20
# epoch 6, train 60/100, loss=0.0306 acc=1.0000
# 20
# epoch 6, train 61/100, loss=0.1640 acc=0.9333
# 20
# epoch 6, train 62/100, loss=0.9450 acc=0.8667
# 20
# epoch 6, train 63/100, loss=0.1164 acc=0.9333
# 20
# epoch 6, train 64/100, loss=0.0290 acc=1.0000
# 20
# epoch 6, train 65/100, loss=0.5197 acc=0.9333
# 20
# epoch 6, train 66/100, loss=0.3829 acc=0.8667
# 20
# epoch 6, train 67/100, loss=0.0170 acc=1.0000
# 20
# epoch 6, train 68/100, loss=0.2958 acc=0.9333
# 20
# epoch 6, train 69/100, loss=0.0412 acc=1.0000
# 20
# epoch 6, train 70/100, loss=0.0106 acc=1.0000
# 20
# epoch 6, train 71/100, loss=0.0161 acc=1.0000
# 20
# epoch 6, train 72/100, loss=0.3839 acc=0.9333
# 20
# epoch 6, train 73/100, loss=0.0938 acc=1.0000
# 20
# epoch 6, train 74/100, loss=0.0665 acc=1.0000
# 20
# epoch 6, train 75/100, loss=0.0140 acc=1.0000
# 20
# epoch 6, train 76/100, loss=0.0339 acc=1.0000
# 20
# epoch 6, train 77/100, loss=0.0216 acc=1.0000
# 20
# epoch 6, train 78/100, loss=0.0403 acc=1.0000
# 20
# epoch 6, train 79/100, loss=0.0081 acc=1.0000
# 20
# epoch 6, train 80/100, loss=0.0225 acc=1.0000
# 20
# epoch 6, train 81/100, loss=0.0071 acc=1.0000
# 20
# epoch 6, train 82/100, loss=0.0169 acc=1.0000
# 20
# epoch 6, train 83/100, loss=0.0461 acc=1.0000
# 20
# epoch 6, train 84/100, loss=0.0440 acc=1.0000
# 20
# epoch 6, train 85/100, loss=0.4554 acc=0.8667
# 20
# epoch 6, train 86/100, loss=0.0050 acc=1.0000
# 20
# epoch 6, train 87/100, loss=0.0872 acc=1.0000
# 20
# epoch 6, train 88/100, loss=0.0015 acc=1.0000
# 20
# epoch 6, train 89/100, loss=0.1582 acc=0.9333
# 20
# epoch 6, train 90/100, loss=0.1742 acc=0.9333
# 20
# epoch 6, train 91/100, loss=0.2214 acc=0.9333
# 20
# epoch 6, train 92/100, loss=0.0763 acc=1.0000
# 20
# epoch 6, train 93/100, loss=0.0248 acc=1.0000
# 20
# epoch 6, train 94/100, loss=0.0129 acc=1.0000
# 20
# epoch 6, train 95/100, loss=0.0028 acc=1.0000
# 20
# epoch 6, train 96/100, loss=0.0973 acc=0.9333
# 20
# epoch 6, train 97/100, loss=0.0019 acc=1.0000
# 20
# epoch 6, train 98/100, loss=0.0004 acc=1.0000
# 20
# ...
# 20
# epoch 49, train 31/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 32/100, loss=0.0112 acc=1.0000
# 20
# epoch 49, train 33/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 34/100, loss=0.0003 acc=1.0000
# 20
# epoch 49, train 35/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 36/100, loss=0.0003 acc=1.0000
# 20
# epoch 49, train 37/100, loss=0.0003 acc=1.0000
# 20
# epoch 49, train 38/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 39/100, loss=0.0059 acc=1.0000
# 20
# epoch 49, train 40/100, loss=0.0005 acc=1.0000
# 20
# epoch 49, train 41/100, loss=0.0009 acc=1.0000
# 20
# epoch 49, train 42/100, loss=0.0001 acc=1.0000
# 20
# epoch 49, train 43/100, loss=0.0004 acc=1.0000
# 20
# epoch 49, train 44/100, loss=0.0040 acc=1.0000
# 20
# epoch 49, train 45/100, loss=0.0001 acc=1.0000
# 20
# epoch 49, train 46/100, loss=0.0002 acc=1.0000
# 20
# epoch 49, train 47/100, loss=0.0001 acc=1.0000
# 20
# epoch 49, train 48/100, loss=0.0002 acc=1.0000
# 20
# epoch 49, train 49/100, loss=0.0026 acc=1.0000
# 20
# epoch 49, train 50/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 51/100, loss=0.0001 acc=1.0000
# 20
# epoch 49, train 52/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 53/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 54/100, loss=0.0001 acc=1.0000
# 20
# epoch 49, train 55/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 56/100, loss=0.0003 acc=1.0000
# 20
# epoch 49, train 57/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 58/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 59/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 60/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 61/100, loss=0.0018 acc=1.0000
# 20
# epoch 49, train 62/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 63/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 64/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 65/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 66/100, loss=0.0002 acc=1.0000
# 20
# epoch 49, train 67/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 68/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 69/100, loss=0.0621 acc=1.0000
# 20
# epoch 49, train 70/100, loss=0.0002 acc=1.0000
# 20
# epoch 49, train 71/100, loss=0.0007 acc=1.0000
# 20
# epoch 49, train 72/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 73/100, loss=0.0001 acc=1.0000
# 20
# epoch 49, train 74/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 75/100, loss=0.1549 acc=0.9333
# 20
# epoch 49, train 76/100, loss=0.0018 acc=1.0000
# 20
# epoch 49, train 77/100, loss=0.0022 acc=1.0000
# 20
# epoch 49, train 78/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 79/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 80/100, loss=0.0001 acc=1.0000
# 20
# epoch 49, train 81/100, loss=0.0014 acc=1.0000
# 20
# epoch 49, train 82/100, loss=0.0012 acc=1.0000
# 20
# epoch 49, train 83/100, loss=0.0062 acc=1.0000
# 20
# epoch 49, train 84/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 85/100, loss=0.0001 acc=1.0000
# 20
# epoch 49, train 86/100, loss=0.0020 acc=1.0000
# 20
# epoch 49, train 87/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 88/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 89/100, loss=0.0003 acc=1.0000
# 20
# epoch 49, train 90/100, loss=0.3163 acc=0.8667
# 20
# epoch 49, train 91/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 92/100, loss=0.0028 acc=1.0000
# 20
# epoch 49, train 93/100, loss=0.0003 acc=1.0000
# 20
# epoch 49, train 94/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 95/100, loss=0.0000 acc=1.0000
# 20
# epoch 49, train 96/100, loss=0.0001 acc=1.0000
# 20
# epoch 49, train 97/100, loss=0.0002 acc=1.0000
# 20
# epoch 49, train 98/100, loss=0.0115 acc=1.0000
# 20
# epoch 49, train 99/100, loss=0.0005 acc=1.0000
# 20
# epoch 49, train 100/100, loss=0.0000 acc=1.0000
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# epoch 49, val, loss=0.0895 acc=0.9727
# ETA:5m/6m
# 20
# epoch 50, train 1/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 2/100, loss=0.0001 acc=1.0000
# 20
# epoch 50, train 3/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 4/100, loss=0.0011 acc=1.0000
# 20
# epoch 50, train 5/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 6/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 7/100, loss=0.0003 acc=1.0000
# 20
# epoch 50, train 8/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 9/100, loss=0.0006 acc=1.0000
# 20
# epoch 50, train 10/100, loss=0.0023 acc=1.0000
# 20
# epoch 50, train 11/100, loss=0.0014 acc=1.0000
# 20
# epoch 50, train 12/100, loss=0.0078 acc=1.0000
# 20
# epoch 50, train 13/100, loss=0.0005 acc=1.0000
# 20
# epoch 50, train 14/100, loss=0.0001 acc=1.0000
# 20
# epoch 50, train 15/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 16/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 17/100, loss=0.0868 acc=0.9333
# 20
# epoch 50, train 18/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 19/100, loss=0.0001 acc=1.0000
# 20
# epoch 50, train 20/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 21/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 22/100, loss=0.0730 acc=0.9333
# 20
# epoch 50, train 23/100, loss=0.0001 acc=1.0000
# 20
# epoch 50, train 24/100, loss=0.0058 acc=1.0000
# 20
# epoch 50, train 25/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 26/100, loss=0.0001 acc=1.0000
# 20
# epoch 50, train 27/100, loss=0.0004 acc=1.0000
# 20
# epoch 50, train 28/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 29/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 30/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 31/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 32/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 33/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 34/100, loss=0.0197 acc=1.0000
# 20
# epoch 50, train 35/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 36/100, loss=0.0908 acc=0.9333
# 20
# epoch 50, train 37/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 38/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 39/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 40/100, loss=0.0001 acc=1.0000
# 20
# epoch 50, train 41/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 42/100, loss=0.0845 acc=0.9333
# 20
# epoch 50, train 43/100, loss=0.0006 acc=1.0000
# 20
# epoch 50, train 44/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 45/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 46/100, loss=0.0012 acc=1.0000
# 20
# epoch 50, train 47/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 48/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 49/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 50/100, loss=0.0003 acc=1.0000
# 20
# epoch 50, train 51/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 52/100, loss=0.0001 acc=1.0000
# 20
# epoch 50, train 53/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 54/100, loss=0.0463 acc=1.0000
# 20
# epoch 50, train 55/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 56/100, loss=0.0003 acc=1.0000
# 20
# epoch 50, train 57/100, loss=0.0060 acc=1.0000
# 20
# epoch 50, train 58/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 59/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 60/100, loss=0.0006 acc=1.0000
# 20
# epoch 50, train 61/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 62/100, loss=0.0096 acc=1.0000
# 20
# epoch 50, train 63/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 64/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 65/100, loss=0.0016 acc=1.0000
# 20
# epoch 50, train 66/100, loss=0.0008 acc=1.0000
# 20
# epoch 50, train 67/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 68/100, loss=0.0002 acc=1.0000
# 20
# epoch 50, train 69/100, loss=0.0025 acc=1.0000
# 20
# epoch 50, train 70/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 71/100, loss=0.0003 acc=1.0000
# 20
# epoch 50, train 72/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 73/100, loss=0.0005 acc=1.0000
# 20
# epoch 50, train 74/100, loss=0.0008 acc=1.0000
# 20
# epoch 50, train 75/100, loss=0.0001 acc=1.0000
# 20
# epoch 50, train 76/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 77/100, loss=0.0001 acc=1.0000
# 20
# epoch 50, train 78/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 79/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 80/100, loss=0.0001 acc=1.0000
# 20
# epoch 50, train 81/100, loss=0.0001 acc=1.0000
# 20
# epoch 50, train 82/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 83/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 84/100, loss=0.0005 acc=1.0000
# 20
# epoch 50, train 85/100, loss=0.0054 acc=1.0000
# 20
# epoch 50, train 86/100, loss=0.0013 acc=1.0000
# 20
# epoch 50, train 87/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 88/100, loss=0.0003 acc=1.0000
# 20
# epoch 50, train 89/100, loss=0.0010 acc=1.0000
# 20
# epoch 50, train 90/100, loss=0.0003 acc=1.0000
# 20
# epoch 50, train 91/100, loss=0.0007 acc=1.0000
# 20
# epoch 50, train 92/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 93/100, loss=0.0001 acc=1.0000
# 20
# epoch 50, train 94/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 95/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 96/100, loss=0.0015 acc=1.0000
# 20
# epoch 50, train 97/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 98/100, loss=0.0000 acc=1.0000
# 20
# epoch 50, train 99/100, loss=0.0037 acc=1.0000
# 20
# epoch 50, train 100/100, loss=0.0000 acc=1.0000
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# torch.Size([15])
# torch.Size([15, 5])
# epoch 50, val, loss=0.2634 acc=0.9620
# ETA:6m/6m

# %% [markdown]
# # 测试模型

# %%
load='./save_protonet/max-acc.pth'


#导出训练得最佳准确数的模型
model = Convnet().cuda()
model.load_state_dict(torch.load(load))
#模型验证
model.eval()

ave_acc = Averager()

for i, batch in enumerate(test_loader, 1):
    data, _ = [_.cuda() for _ in batch]
    print(data.shape)
    k = way * shot
    data_shot, data_query = data[:k], data[k:]

    x = model(data_shot)  #在支持集上前传的结果
    x = x.reshape(shot, way, -1).mean(dim=0)  #计算支持集每类样本的均值==》原型
    p = x

    logits = euclidean_metric(model(data_query), p)

    label = torch.arange(test_way).repeat(query)
    label = label.type(torch.cuda.LongTensor)

#     print(label.shape)
#     print(logits.shape)

    acc = count_acc(logits, label)
    ave_acc.add(acc)
    print('batch {}: {:.2f}({:.2f})'.format(i, ave_acc.item() * 100, acc * 100))
        
    x = None; p = None; logits = None
# Out:
# torch.Size([20, 1, 30, 30])
# batch 1: 100.00(100.00)
# torch.Size([20, 1, 30, 30])
# batch 2: 93.33(86.67)
# torch.Size([20, 1, 30, 30])
# batch 3: 95.56(100.00)
# torch.Size([20, 1, 30, 30])
# batch 4: 96.67(100.00)
# torch.Size([20, 1, 30, 30])
# batch 5: 97.33(100.00)
# torch.Size([20, 1, 30, 30])
# batch 6: 97.78(100.00)
# torch.Size([20, 1, 30, 30])
# batch 7: 98.10(100.00)
# torch.Size([20, 1, 30, 30])
# batch 8: 98.33(100.00)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-7da450929237> in <module>
#      10 ave_acc = Averager()
#      11
# ---> 12 for i, batch in enumerate(test_loader, 1):
#      13     data, _ = [_.cuda() for _ in batch]
#      14     print(data.shape)
#
# D:\anconda\envs\pyenv\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     612     def __next__(self):
#     613         if self.num_workers == 0:  # same-process loading
# --> 614             indices = next(self.sample_iter)  # may raise StopIteration
#     615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#
# <ipython-input-4-8ee26f00b1ea> in __iter__(self)
#      27                 pos = torch.randperm(len(l))[:self.n_per]  #从选出的每个类中随机取出n_per个样本
#      28                 batch.append(l[pos])
# ---> 29             batch = torch.stack(batch).t().reshape(-1)  #batch保存一个eposide所需的所有样本的索引，注意.t()是按（s+q）个存放
#      30             yield batch  #返回一个n way k shot任务需要的样本，即n*(s+q)
#
# RuntimeError: invalid argument 0: Sizes of tensors must match except in dimension 0. Got 4 and 2 in dimension 1 at c:\a\w\1\s\windows\pytorch\aten\src\th\generic/THTensorMoreMath.cpp:1307
